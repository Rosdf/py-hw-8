# %%
#задание 2
import requests
class Rate:
    def __init__(self, format_='value', diff_=False):
        self.format = format_
        self.diff = diff_
    
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return r.json()['Valute']
    
    def make_format(self, currency):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                return response[currency]['Value']
        
        return 'Error'
    
    def eur(self):
        """Возвращает курс евро на сегодня в формате self.format"""
        if self.format == 'full':
            return self.make_format('EUR')
        if self.format == 'value':
            if self.diff == False:
                return self.make_format('EUR')
            if self.diff == True:
                r = self.exchange_rates()
                return r['EUR']['Value'] - r['EUR']['Previous']
        return 'Error'
                
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        if self.format == 'full':
            return self.make_format('USD')
        if self.format == 'value':
            if self.diff == False:
                return self.make_format('USD')
            if self.diff == True:
                r = self.exchange_rates()
                return r['USD']['Value'] - r['USD']['Previous']
        return 'Error'

    def AZN(self):
        """Возвращает курс азербайджанского маната на сегодня в формате self.format"""
        if self.format == 'full':
            return self.make_format('AZN')
        if self.format == 'value':
            if self.diff == False:
                return self.make_format('AZN')
            if self.diff == True:
                r = self.exchange_rates()
                return r['AZN']['Value'] - r['AZN']['Previous']
        return 'Error'

# %%
r = Rate()
r.diff = True
r.usd()

# %%
#задание 1
def highest_value():
    r = Rate()
    rv = r.exchange_rates()
    max_ = 0
    max_name = ""
    for curency in rv.values():
        if curency["Value"] > max_:
            max_ = curency["Value"]
            max_name = curency["Name"]
    return max_name

# %%
highest_value()

# %%
class Employee:
    def __init__(self, name, seniority):
        self.name = name
        self.seniority = seniority
        
        self.grade = 1
    
    def grade_up(self):
        """Повышает уровень сотрудника"""
        self.grade += 1
    
    def publish_grade(self):
        """Публикация результатов аккредитации сотрудников"""
        print(self.name, self.grade)
    
    def check_if_it_is_time_for_upgrade(self):
        pass

# %%
#задание 3
class Designer(Employee):
    def __init__(self, name, seniority, prize=2):
        super().__init__(name, seniority)
        self.prize = prize
        self.seniority = 2 * prize
    
    def check_if_it_is_time_for_upgrade(self):
        """проверяет пора ли повысить сотрудника"""
        if self.seniority % 7 == 0:
            self.grade_up()
    def one_more_prize(self, num=1):
        """увеличивает число международных премий, по умолчанию num=1"""
        self.prize += num
        self.seniority += 2 * num
        self.check_if_it_is_time_for_upgrade()
    def one_more_accreditation(self, num=1):
        """увеличивает число пройденых аккредитаций, по умолчанию num=1"""
        self.seniority += num
        self.check_if_it_is_time_for_upgrade()
